# %%
import pandas as pd

# %%
url ='https://raw.githubusercontent.com/tenoriometro/tenoriometro-CoderHouse_DS_MTENORIO/main/Datasets_desafios/Google_data_cleaned.csv'

df = pd.read_csv(url)

# %%
df.head()
# Out:
#    Unnamed: 0                                                app  \
# 0           0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1           1                                Coloring book moana
# 2           2  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3           3                              Sketch - Draw & Paint
# 4           4              Pixel Draw - Number Art Coloring Book
#
#          category  rating  reviews  installs  type  price content_rating  \
# 0  ART_AND_DESIGN     4.1      159     10000     0    0.0       Everyone
# 1  ART_AND_DESIGN     3.9      967    500000     0    0.0       Everyone
# 2  ART_AND_DESIGN     4.7    87510   5000000     0    0.0       Everyone
# 3  ART_AND_DESIGN     4.5   215644  50000000     0    0.0           Teen
# 4  ART_AND_DESIGN     4.3      967    100000     0    0.0       Everyone
#
#                       genres current_ver android_ver  size(kb)  update_month  \
# ...
