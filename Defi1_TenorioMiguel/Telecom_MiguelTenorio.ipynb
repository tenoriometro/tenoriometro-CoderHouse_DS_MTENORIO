# %%
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/tenoriometro/tenoriometro-CoderHouse_DS_MTENORIO/main/Datasets_desafios/Telecom%20Churn%20Rate%20Dataset.csv'
df = pd.read_csv(url, sep=';')

# %%
df.head(5
)

# %%
url = 'https://raw.githubusercontent.com/tenoriometro/tenoriometro-CoderHouse_DS_MTENORIO/main/Datasets_desafios/Telecom%20Company%20Call-Center-Dataset.csv'
df2 = pd.read_csv(url, sep=';')

# %%
df2.head()
